# %% [markdown]
# ## PALABRAS RESERVADAS (EJEMPLO)

# %%
#ejemplo con import math

# %% [markdown]
# ## COMENTARIOS (EJEMPLO)

# %%
#comentario mono línea

# %%
'''
comentario
multilínea
'''

# %% [markdown]
# ## FRASES

# %%
a=5

# %%
c=10/a

# %%
str(c)

# %% [markdown]
# ## PÁRRAFOS

# %%
a=3
c=10/a
print(c)

# %% [markdown]
# ## VARIABLES

# %%
numero = 0
cadena = "hola mundo"​
diccionario = {"mybar":"valor"}​
lista = ["dato1","dato2"]​
tupla = ("manzana", "pera")

# %% [markdown]
# ## CONSTANTES
# *convención de nomenclatura*

# %%
GRAVEDAD= 9.8

# %%
t = 10
v = t * GRAVEDAD
print(v)
