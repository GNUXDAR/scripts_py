# %% [markdown]
# # Primero te lo explico

# %%
def suma3y5():
  print(f'el resultado es {3+5}')

# %% [markdown]
# # Luego lo haces

# %%
suma3y5()

# %% [markdown]
# y podemos añadir toda la funcionalidad que queramos ejecutar tal y como hacemos con los bloques de jupiter
