# %% [markdown]
# #Funcionalidad de las cadenas

# %%
refran = "El perro de San Roque no tiene rabo ...    "

# %% [markdown]
# ## También podemos acceder a funcionalidad más compleja

# %%
help(refran)

# %%
help(str)

# %% [markdown]
# Todo bien explicado en la documentación de python
# [https://docs.python.org/3.8/library/stdtypes.html#string-methods](https://docs.python.org/3.8/library/stdtypes.html#string-methods)

# %% [markdown]
# ## veamos algunos de los más usados

# %%
refran.lower()
# Out:
# 'el perro de san roque no tiene rabo ...'

# %%
refran.upper()
# Out:
# 'EL PERRO DE SAN ROQUE NO TIENE RABO ...'

# %%
refran.capitalize()
# Out:
# 'El perro de san roque no tiene rabo ...'

# %%
refran.replace('no','si')
# Out:
# 'El perro de San Roque si tiene rabo ...'

# %%
refran.find('Roque')
# Out:
# 16

# %%
refran.find('roque')
# Out:
# -1

# %%
refran.lower().find('roque')
# Out:
# 16

# %%
refran.strip()
# Out:
# 'El perro de San Roque no tiene rabo ...'

# %%
refran.split()
# Out:
# ['El', 'perro', 'de', 'San', 'Roque', 'no', 'tiene', 'rabo', '...']

# %%
refran.split('no')
# Out:
# ['El perro de San Roque ', ' tiene rabo ...']
