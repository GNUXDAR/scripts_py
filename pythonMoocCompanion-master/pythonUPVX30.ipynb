# %% [markdown]
# # Os acordais del import math de uno de los primeros videos?
# -lo vimos cuando hablábamos de las palabras claves

# %%
import math

# %% [markdown]
# con los comandos help/dir podremos saber lo que hay en el módulo

# %%
help(math)

# %% [markdown]
# y podemos usar las recetas de otros

# %%
math.cos(math.pi)

# %% [markdown]
# pero a veces el módulo no esta?

# %%
import libxslt

# %% [markdown]
# lo podremos instalar de distintas maneras

# %% [markdown]
# ### Creando nuestras propias recetas
# vamos a crear libroderecetas.py con la constante de GRAVEDAD y la funcion miSuma
#
# ### Ahora podemos usar tu libroderecetas

# %%
import libroderecetas

# %% [markdown]
# podremos acceder a la constante que hemos declarado

# %%
libroderecetas.GRAVEDAD

# %% [markdown]
# y usar la funcion suma

# %%
print(libroderecetas.miSuma(3,7))
