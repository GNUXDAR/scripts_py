# %% [markdown]
# # MODULOS PAQUETES Y NAMESPACES
# #### MÓDULOS
# cada uno de los archivos .py que generamos en python se denominan módulos, y son considerados contenedores para organizar nuestro código
#
# #### PAQUETES
# un paquete es un módulo que sirve para contener otros módulos y paquetes, en la práctica es un directorio que contiene un archivo '__init __.py'
#
# dentro de dicho directorio podremos tener almacenados otros módulos o paquetes
# ![](https://i.imgur.com/OGmF7Kk.png)

# %%
import libroderecetas2 #importamos un modulo
import estanteria.libroderecetas1 # un modulo incluido dentro de un paquete

# %% [markdown]
# ### Espacios de nombres (namespaces)
# le diremos a python de que libro de recetas ó estantería (módulo ó paquete) queremos que nos de información ó use funciones

# %%
print (libroderecetas2.CONST)
print (estanteria.libroderecetas1.CONST)

# %% [markdown]
# Es como pedirle la receta de la hamburgesa del libro de recetas clásico ó la hamburguesa del libro de recetas vegano, la receta se llama igual pero dependiendo del libro de recetas es una cosa o otra.

# %% [markdown]
# ## organizando nuestro código
#
# * src
#   * principal .py
#   * paquetededatos
#     * transacciones.py
#   * paquetedevisualización
#     * graficas.py
#     * plantillas.py
#   * paqueteconfuncionesauxisliares
#     * auxiliaresmatematicas.py
#     * auxiliaresfechas.py
# * assets
#   * img
#     * fondo.png
#     * logo.png
#   * language
#     * spanish.json
#     * english.json
