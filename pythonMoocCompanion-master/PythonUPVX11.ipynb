# %% [markdown]
# # Tipado dinámico

# %%
miVariable = 3

# %%
miVariable = "Hola"

# %%
miVariable = 3.0 + 2j

# %% [markdown]
# #Fuertemente tipado

# %%
numero = 33
cadena = "hola"

# %%
numero + 2
# Out:
# 35

# %%
cadena + " mundo"
# Out:
# 'hola mundo'

# %%
cadena + numero
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cadena + numero
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# #Tipos de datos numéricos

# %%
entero = 4
entero_largo = 3L

# %%
real = 3.0

# %%
complejo = 2 + 1j

# %% [markdown]
# #Tipos de datos lógicos

# %%
variable_logica = True

# %% [markdown]
# #Tipos de datos sequenciales

# %%
cadena ="hola caracola"
cadena
# Out:
# 'hola caracola'

# %%
lista =["pera","manzana","piña"]
lista[0]
# Out:
# 'pera'

# %%
tupla = ("pera","manzana","piña")
tupla
# Out:
# ('pera', 'manzana', 'piña')

# %% [markdown]
# #Diccionarios

# %%
diccionario = {"nombre":"Arturo", "apellidos": "Cabrera", "nick": "@gnuxdar"}
diccionario["nick"]
# Out:
# '@gnuxdar'
