# %% [markdown]
# # Trabajando con cadenas

# %%
refran = "El perro de San Roque no tiene rabo ..."

# %%
len(refran)

# %% [markdown]
# podemos acceder a los carácteres que componen la cadena por su índice

# %%
refran[0]

# %%
refran[39]

# %% [markdown]
# incluso a trozos de cadena

# %%
refran[0:10]
# Out:
# 'El perro d'

# %%
refran[10:20]

# %%
refran[:20]
# Out:
# 'El perro de San Roqu'

# %%
refran[20:]
# Out:
# 'e no tiene rabo ...'

# %%
refran[:-10]
# Out:
# 'El perro de San Roque no tien'

# %%
refran[-10:]
# Out:
# 'e rabo ...'
