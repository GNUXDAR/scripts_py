# %% [markdown]
# #Operaciones lógicas

# %%
tres = 3
cinco = 5

# %% [markdown]
# Comparadores

# %%
tres>cinco
# Out:
# False

# %%
tres>=cinco
# Out:
# False

# %%
tres<cinco
# Out:
# True

# %%
tres<=cinco
# Out:
# True

# %%
tres == cinco # no confundir con tres = cinco
# Out:
# False

# %%
"aa" is "a"*2
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_7904/3485029056.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   "aa" is "a"*2
# True

# %%
letraA = "a"
"aa" is letraA * 2
# Out:
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_7904/1605568633.py:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   "aa" is letraA * 2
# False

# %% [markdown]
# Conectores lógicos

# %%
verdadero=True
falso=False
# Out:
# <class 'tuple'>

# %%
verdadero and falso
# Out:
# False

# %%
verdadero or falso
# Out:
# True

# %%
not verdadero
# Out:
# False
